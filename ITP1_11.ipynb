# %%
#A
Dice=list(map(int,input().split()));
t=list(input());

U=Dice[0];
S=Dice[1];
E=Dice[2];
W=Dice[3];
N=Dice[4];
D=Dice[5];
X=0;

for i in t:
    if i=="S":
        X=S;
        S=U;
        U=N
        N=D;
        D=X;
    elif i=="E":
        X=E;
        E=U;
        U=W;
        W=D;
        D=X;
    elif i=="N":
        X=N;
        N=U;
        U=S;
        S=D;
        D=X;    
    elif i=="W":
        X=W;
        W=U;
        U=E;
        E=D;
        D=X;
    
print(U);
# Out:
# 8 7 99 2 88 28
# SE
# 2

# %%
#B
Dice=list(map(int,input().split()));
q=int(input());

U=Dice[0];
S=Dice[1];
E=Dice[2];
W=Dice[3];
N=Dice[4];
D=Dice[5];


for i in range(q):
    u,s=map(int,input().split());
    if u==U:
        if s==S:
            print(E);
        elif s==E:
            print(N);
        elif s==N:
            print(W);
        elif s==W:
            print(S);
    elif u==S:
        if s==D:
            print(E);
        elif s==E:
            print(U);
        elif s==U:
            print(W);
        elif s==W:
            print(D);
    elif u==D:
        if s==N:
            print(E);
        elif s==E:
            print(S);
        elif s==S:
            print(W);
        elif s==W:
            print(N);       
    elif u==N:
        if s==U:
            print(E);
        elif s==E:
            print(D);
        elif s==D:
            print(W);
        elif s==W:
            print(U);         
    elif u==E:
        if s==S:
            print(D);
        elif s==D:
            print(N);
        elif s==N:
            print(U);
        elif s==U:
            print(S);         
    elif u==W:
        if s==D:
            print(S);
        elif s==S:
            print(U);
        elif s==U:
            print(N);
        elif s==N:
            print(D);
# Out:
# 1 2 3 4 5 6
# 3
# 6 5
# 3
# 1 3
# 5
# 3 2
# 6

# %%
#C
Dice1=list(map(int,input().split()));
Dice2=list(map(int,input().split()));
x=0;

U1=Dice1[0];
S1=Dice1[1];
E1=Dice1[2];
W1=Dice1[3];
N1=Dice1[4];
D1=Dice1[5];

U2=Dice2[0];
S2=Dice2[1];
E2=Dice2[2];
W2=Dice2[3];
N2=Dice2[4];
D2=Dice2[5];

#U
if U1==U2 and S1==S2 and E1==E2 and N1==N2 and W1==W2 and D1==D2:
    x=1;
elif U1==U2 and S1==E2 and E1==N2 and N1==W2 and W1==S2 and D1==D2:
    x=1;
elif U1==U2 and S1==N2 and E1==W2 and N1==S2 and W1==E2 and D1==D2:
    x=1;
elif U1==U2 and S1==W2 and E1==S2 and N1==E2 and W1==N2 and D1==D2:
    x=1;

#S    
elif U1==S2 and S1==D2 and E1==E2 and N1==U2 and W1==W2 and D1==N2:
    x=1;
elif U1==S2 and S1==E2 and E1==U2 and N1==W2 and W1==D2 and D1==N2:
    x=1;
elif U1==S2 and S1==U2 and E1==W2 and N1==D2 and W1==E2 and D1==N2:
    x=1;
elif U1==S2 and S1==W2 and E1==D2 and N1==E2 and W1==U2 and D1==N2:
    x=1;
    
#D  
elif U1==D2 and S1==N2 and E1==E2 and N1==S2 and W1==W2 and D1==U2:
    x=1;
elif U1==D2 and S1==E2 and E1==S2 and N1==W2 and W1==N2 and D1==U2:
    x=1;
elif U1==D2 and S1==S2 and E1==W2 and N1==N2 and W1==E2 and D1==U2:
    x=1;
elif U1==D2 and S1==W2 and E1==N2 and N1==E2 and W1==S2 and D1==U2:
    x=1;

#N
elif U1==N2 and S1==U2 and E1==E2 and N1==D2 and W1==W2 and D1==S2:
    x=1;
elif U1==N2 and S1==E2 and E1==D2 and N1==W2 and W1==U2 and D1==S2:
    x=1;
elif U1==N2 and S1==D2 and E1==W2 and N1==U2 and W1==E2 and D1==S2:
    x=1;
elif U1==N2 and S1==W2 and E1==U2 and N1==E2 and W1==D2 and D1==S2:
    x=1;

#E    
elif U1==E2 and S1==S2 and E1==D2 and N1==N2 and W1==U2 and D1==W2:
    x=1;
elif U1==E2 and S1==D2 and E1==N2 and N1==U2 and W1==S2 and D1==W2:
    x=1;
elif U1==E2 and S1==N2 and E1==U2 and N1==S2 and W1==D2 and D1==W2:
    x=1;
elif U1==E2 and S1==U2 and E1==S2 and N1==D2 and W1==N2 and D1==W2:
    x=1;
    
#W
elif U1==W2 and S1==S2 and E1==U2 and N1==N2 and W1==D2 and D1==E2:
    x=1;
elif U1==W2 and S1==U2 and E1==N2 and N1==D2 and W1==S2 and D1==E2:
    x=1;
elif U1==W2 and S1==N2 and E1==D2 and N1==S2 and W1==U2 and D1==E2:
    x=1;
elif U1==W2 and S1==D2 and E1==S2 and N1==U2 and W1==N2 and D1==E2:
    x=1;



if x==1:
    print("Yes");
else:
    print("No");
# Out:
# 1 2 3 4 5 6
# 6 2 4 3 5 1
# Yes

# %%
#D
n=int(input());
Dices=[];
a=0;

for i in range(n):
    Dice=list(map(int,input().split()));
    Dices.append(Dice);
    
def compare(Dice1,Dice2):
    U1=Dice1[0];
    S1=Dice1[1];
    E1=Dice1[2];
    W1=Dice1[3];
    N1=Dice1[4];
    D1=Dice1[5];

    U2=Dice2[0];
    S2=Dice2[1];
    E2=Dice2[2];
    W2=Dice2[3];
    N2=Dice2[4];
    D2=Dice2[5];
    x=0;
    
    #U
    if U1==U2 and S1==S2 and E1==E2 and N1==N2 and W1==W2 and D1==D2:
        x=1;
    elif U1==U2 and S1==E2 and E1==N2 and N1==W2 and W1==S2 and D1==D2:
        x=1;
    elif U1==U2 and S1==N2 and E1==W2 and N1==S2 and W1==E2 and D1==D2:
        x=1;
    elif U1==U2 and S1==W2 and E1==S2 and N1==E2 and W1==N2 and D1==D2:
        x=1;

    #S    
    elif U1==S2 and S1==D2 and E1==E2 and N1==U2 and W1==W2 and D1==N2:
        x=1;
    elif U1==S2 and S1==E2 and E1==U2 and N1==W2 and W1==D2 and D1==N2:
        x=1;
    elif U1==S2 and S1==U2 and E1==W2 and N1==D2 and W1==E2 and D1==N2:
        x=1;
    elif U1==S2 and S1==W2 and E1==D2 and N1==E2 and W1==U2 and D1==N2:
        x=1;
    
    #D  
    elif U1==D2 and S1==N2 and E1==E2 and N1==S2 and W1==W2 and D1==U2:
        x=1;
    elif U1==D2 and S1==E2 and E1==S2 and N1==W2 and W1==N2 and D1==U2:
        x=1;
    elif U1==D2 and S1==S2 and E1==W2 and N1==N2 and W1==E2 and D1==U2:
        x=1;
    elif U1==D2 and S1==W2 and E1==N2 and N1==E2 and W1==S2 and D1==U2:
        x=1;

    #N
    elif U1==N2 and S1==U2 and E1==E2 and N1==D2 and W1==W2 and D1==S2:
        x=1;
    elif U1==N2 and S1==E2 and E1==D2 and N1==W2 and W1==U2 and D1==S2:
        x=1;
    elif U1==N2 and S1==D2 and E1==W2 and N1==U2 and W1==E2 and D1==S2:
        x=1;
    elif U1==N2 and S1==W2 and E1==U2 and N1==E2 and W1==D2 and D1==S2:
        x=1;

    #E    
    elif U1==E2 and S1==S2 and E1==D2 and N1==N2 and W1==U2 and D1==W2:
        x=1;
    elif U1==E2 and S1==D2 and E1==N2 and N1==U2 and W1==S2 and D1==W2:
        x=1;
    elif U1==E2 and S1==N2 and E1==U2 and N1==S2 and W1==D2 and D1==W2:
        x=1;
    elif U1==E2 and S1==U2 and E1==S2 and N1==D2 and W1==N2 and D1==W2:
        x=1;
    
    #W
    elif U1==W2 and S1==S2 and E1==U2 and N1==N2 and W1==D2 and D1==E2:
        x=1;
    elif U1==W2 and S1==U2 and E1==N2 and N1==D2 and W1==S2 and D1==E2:
        x=1;
    elif U1==W2 and S1==N2 and E1==D2 and N1==S2 and W1==U2 and D1==E2:
        x=1;
    elif U1==W2 and S1==D2 and E1==S2 and N1==U2 and W1==N2 and D1==E2:
        x=1;
        
    return x;
    
    
for i in range(n):
    for j in range(n):
        if i!=j:
            a+=compare(Dices[i],Dices[j]);

if a==0:
    print("Yes");
else:
    print("No");
# Out:
# 3
# 1 2 3 4 5 6
# 6 5 4 3 2 1
# 5 4 3 2 1 6
# Yes
