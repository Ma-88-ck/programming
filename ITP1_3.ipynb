# %%
#A
i=0;
for i in range(1000):
    print("Hello World");
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# ...

# %%
#B
x,n,i=1,1,0;
L=[];
while x!=0:
    x=int(input());
    L.insert(i,x);
    i=i+1;
    
for n in range(len(L)-1):
    print("Case "+str(n+1)+": "+str(L[n]));
# Out:
# 1
# 2
# 3
# 4
# 4
# 0
# Case 1: 1
# Case 2: 2
# Case 3: 3
# Case 4: 4
# Case 5: 4

# %%
#C
a,b,n=1,1,0;
s,l=[],[];
while True:
    a,b=map(int,input().split());
    if a<b:
        print(str(a)+" "+str(b));
    elif a==0 and b==0:
        break;
    else:
        print(str(b)+" "+str(a));
# Out:
# 1 2
# 1 2
# 0 0

# %%
#D
a,b,c=map(int,input().split());
count=0;
for i in range(a,b+1):
    if c%i==0:
        count=count+1;
    else:
        count=count;
print(count);
# Out:
# 5 14 80
# 3
